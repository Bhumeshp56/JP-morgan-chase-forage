# %% [markdown]
# Gas Price Time-Series Forecasting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('/Users/bhumeshpanchal/Documents/Bhumesh/Mtech/Placement_prep/JPMC_SImulation/nat_gas_price.xlsx')
df.plot(title="Gas prices Oct 2020 - Sept 2024", xlabel="Month", ylabel="Price (US$ per million BTU)")
# Out:
# <Axes: title={'center': 'Gas prices Oct 2020 - Sept 2024'}, xlabel='Month', ylabel='Price (US$ per million BTU)'>

# %%
df_2020 = df.iloc[:12]
df_2020.plot(title="Gas prices Oct 2020 - Sept 2021", xlabel="Month", ylabel="Price (US$ per million BTU)")
# Out:
# <Axes: title={'center': 'Gas prices Oct 2020 - Sept 2021'}, xlabel='Month', ylabel='Price (US$ per million BTU)'>

# %% [markdown]
# Price of natural gas having the cyclical pattern each each year and it increasing every year
#
# For example below results will show for single year
#
# It shows higher prices in winter and relatively lower in summer

# %%
df_2020 = df.iloc[:12]
df_2020.plot(title="Gas prices Oct 2020 - Sept 2021", xlabel="Month", ylabel="Price (US$ per million BTU)")
# Out:
# <Axes: title={'center': 'Gas prices Oct 2020 - Sept 2021'}, xlabel='Month', ylabel='Price (US$ per million BTU)'>

# %%
df_dec = df[df.index % 12 == 2]
df_dec.plot(title="December gas prices 2020 - 2023", xlabel="Month", ylabel="Price (US$ per million BTU)")
# Out:
# <Axes: title={'center': 'December gas prices 2020 - 2023'}, xlabel='Month', ylabel='Price (US$ per million BTU)'>
